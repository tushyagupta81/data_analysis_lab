# %% [markdown]
# 2.Consider an array contains marks of students. Find the median and mean of students who got passing marks.

# %%
import numpy as np

# %%
marks = np.random.rand(100) * 100
print(marks[:10])
# Out:
# [ 5.06410679  4.48844314 45.62135869  1.24852618 16.96693997 22.46321015
#  47.78129135  4.73599573 25.82089114 43.30146921]

# %%
passing_marks = 33
passing_args = np.where(marks > passing_marks)
print(f"Passing indexes = {passing_args}")
print(f"Mean = {marks[passing_args].mean()}")
print(f"Median = {np.median(marks[passing_args])}")
# Out:
# Passing indexes = (array([ 0,  1,  2,  3,  5,  6,  7,  8, 10, 11, 12, 14, 15, 16, 17, 19, 20,
#        22, 23, 26, 27, 30, 31, 33, 36, 37, 44, 45, 46, 47, 48, 49, 50, 53,
#        54, 55, 56, 58, 59, 60, 61, 62, 65, 66, 67, 69, 70, 71, 72, 75, 77,
#        78, 79, 80, 81, 83, 86, 88, 89, 90, 91, 93, 94, 97, 98]),)
# Mean = 64.30999268096525
# Median = 64.44895422693902
