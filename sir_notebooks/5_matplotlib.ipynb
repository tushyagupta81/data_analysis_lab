# %% [markdown]
# ## Matplotlib
# (c) Naveen Aggarwal

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.plot([1, 2, 3, 4, 5, 6, 7])
plt.ylabel("Some significant numbers on Y Axis")
plt.xlabel("Total Range on X-axis")
plt.show()

# %%
import numpy as np

# evenly sampled time at .2 intervals
t = np.arange(0.0, 5.0, 0.2)
# red dashes, blue squares and green triangles

print(t)
plt.plot(t, t, "r--")
plt.axis([0, 6, 0, 150])  # x and y range of axis
plt.show()
plt.plot(t, t, "b--", t, t**2, "bs", t, t**3, "g^")
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25], "go-", label="line 1", linewidth=5)
plt.show()

# %% [markdown]
# ### For more information visit the following doc
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.figure(1, figsize=(16, 9))  # Called implicitly
# for multiple figures
plt.subplot(3, 3, 1)  # 2 rows, 1 column, 1st plot
plt.plot(t1, f(t1), "bo", t2, f(t2), "k")
plt.subplot(3, 3, 3)  # 2 rows, 1 column, 1st plot
plt.plot(t1, f(t1), "bo", t2, f(t2), "k")
plt.subplot(3, 3, 5)  # 2 rows, 1 column, 2nd plot
plt.plot(t2, np.cos(2 * np.pi * t2), "r--")
plt.subplot(4, 4, 16)  # 2 rows, 1 column, 2nd plot
plt.plot(t2, np.cos(2 * np.pi * t2), "r--")
plt.subplot(4, 4, 15)  # 2 rows, 1 column, 2nd plot
plt.plot(t2, np.cos(2 * np.pi * t2), "r--")
plt.subplot(4, 4, 14)  # 2 rows, 1 column, 2nd plot
plt.plot(t2, np.cos(2 * np.pi * t2), "r--")
plt.subplot(4, 4, 13)  # 2 rows, 1 column, 2nd plot
plt.plot(t2, np.cos(2 * np.pi * t2), "r--")
plt.show()
# %%

# %% [markdown]
# ##### Create a line graph of CO2 versus time. View the plot.

# %%
times = range(8)
co2 = [250, 265, 272, 260, 300, 320, 389, 403]
plt.plot(times, co2)
plt.plot(times, co2, "b--")
plt.title("Concentration of CO2 versus time")
plt.ylabel("[CO2 Gas]")
plt.xlabel("Time (decade)")
plt.show()

# %% [markdown]
# ##### Continuing with the above data plot, add some additional data

# %%
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2, 22.4]
plt.plot(times, co2, "b--", times, temp, "r*-")
plt.savefig("co2_temp.pdf")
plt.show()

# %% [markdown]
# ##### Multiple axes

# %%
fig, ax1 = plt.subplots()
times = range(8)
co2 = [250, 265, 272, 260, 300, 320, 389, 410]
ax1.plot(times, co2, "b--")
ax1.set_ylabel("[CO2]")
ax2 = ax1.twinx()
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2, 20.8]
ax2.plot(times, temp, "r*-")
ax2.set_ylabel("Temp (degC)")
plt.show()

# %% [markdown]
# ##### Multiple Plots

# %%
plt.subplot(2, 2, 1)
x = range(0, 10, 1)
plt.plot(x)
plt.subplot(2, 2, 2)
y = range(10, 0, -1)
plt.plot(y)
plt.subplot(2, 2, 3)
z = [4] * 10
plt.plot(z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 70, 10
x = mu + sigma * np.random.randn(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor="b", alpha=0.2)
plt.xlabel("Smarts")
plt.ylabel("Probability")
plt.title("Histogram of IQ")
plt.text(60, 0.045, "$\mu=70,\ \sigma=10$", color="r")  # TeX equations
plt.axis([30, 100, 0, 0.05])
plt.grid(True)
plt.show()
print(n, bins, patches)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/q6/q617z1552s929bppjqdg260h0000gn/T/ipykernel_63873/2918665895.py:10: SyntaxWarning: invalid escape sequence '\m'
#   plt.text(60, .045, '$\mu=70,\ \sigma=10$', color='r') #TeX equations
# [0.00029078 0.00043617 0.00065426 0.00050887 0.00116313 0.0015993
#  0.00327129 0.00327129 0.00443442 0.00516137 0.00777841 0.01032275
#  0.01221283 0.01337596 0.01962776 0.02137245 0.02268097 0.02609765
#  0.03096825 0.03547536 0.03663849 0.03714736 0.03976439 0.04049135
#  0.03823779 0.03831048 0.03881935 0.03663849 0.02762426 0.03104094
#  0.02638844 0.02188132 0.01911889 0.0158476  0.01279439 0.01134048
#  0.00726954 0.00690606 0.00654259 0.00450712 0.00290782 0.00130852
#  0.0015993  0.00101774 0.00087234 0.00021809 0.00043617 0.00029078
#  0.00014539 0.00014539] [ 37.39589606  38.77149865  40.14710125  41.52270384  42.89830644
#   44.27390903  45.64951162  47.02511422  48.40071681  49.77631941
#   51.151922    52.5275246   53.90312719  55.27872979  56.65433238
#   58.02993497  59.40553757  60.78114016  62.15674276  63.53234535
#   64.90794795  66.28355054  67.65915314  69.03475573  70.41035833
#   71.78596092  73.16156351  74.53716611  75.9127687   77.2883713
#   78.66397389  80.03957649  81.41517908  82.79078168  84.16638427
#   85.54198686  86.91758946  88.29319205  89.66879465  91.04439724
#   92.41999984  93.79560243  95.17120503  96.54680762  97.92241021
#   99.29801281 100.6736154  102.049218   103.42482059 104.80042319
#  106.17602578] <BarContainer object of 50 artists>

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)
print(x[:10])
print(y[:10])
# Out:
# [0.         0.02004008 0.04008016 0.06012024 0.08016032 0.1002004
#  0.12024048 0.14028056 0.16032064 0.18036072]
# [[ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788]
#  [ 2.71414076  0.2488      0.87551913  2.6514917   2.01160156  0.47699563]
#  [ 3.47517849  0.37047502  1.31938237  2.98516603  3.50568063  0.27183736]
#  [ 3.78824619 -0.48362072 -1.23360745  3.63878462  4.37011683 -0.47032766]
#  [ 6.05800081 -1.9379864  -1.18784893  3.45160077  5.90289605  0.99903111]
#  [ 6.21294824 -1.55982388 -2.07563468  1.47080431  5.5549839   1.15538008]
#  [ 7.44323892 -0.35744403 -2.4629615   1.16850156  4.50643093 -0.26463786]
#  [ 5.73696873  1.59333137 -2.97261368  0.73042725  3.25363557  0.5128525 ]
#  [ 4.12307088  1.38059109 -3.86808024  1.11732975  2.74283044 -0.66777968]
#  [ 4.09488865  1.80892296 -3.80156302  1.41980165  2.10850834 -1.03052085]]

# %%
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend("ABCDEF", ncol=2, loc="upper left");

# %% [markdown]
# Now let's take a look at how it works with Seaborn. As we will see, Seaborn has many of its own high-level plotting routines, but it can also overwrite Matplotlib's default parameters and in turn get even simple Matplotlib scripts to produce vastly superior output. We can set the style by calling Seaborn's set() method. By convention, Seaborn is imported as sns

# %%
import seaborn as sns

# sns.set()
sns.set_theme()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend("ABCDEF", ncol=2, loc="upper left");

# %% [markdown]
# ### Exploring Seaborn Plots
# The main idea of Seaborn is that it provides high-level commands to create a variety of plot types useful for statistical data exploration, and even some statistical model fitting.
#
# Let's take a look at a few of the datasets and plot types available in Seaborn. Note that all of the following could be done using raw Matplotlib commands (this is, in fact, what Seaborn does under the hood) but the Seaborn API is much more convenient.
#
# #### Histograms, KDE, and densities
# Often in statistical data visualization, all you want is to plot histograms and joint distributions of variables. We have seen that this is relatively straightforward in Matplotlib:

# %% [markdown]
# ### Pair plots
# When you generalize joint plots to datasets of larger dimensions, you end up with pair plots. This is very useful for exploring correlations between multidimensional data, when you'd like to plot all pairs of values against each other.
#
# Lets see the demo this with the well-known Iris dataset, which lists measurements of petals and sepals of three iris species:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue="species", height=2.5);

# %% [markdown]
# #### Faceted histograms
# Sometimes the best way to view data is via histograms of subsets. Seaborn's FacetGrid makes this extremely simple. We'll take a look at some data that shows the amount that restaurant staff receive in tips based on various indicator data:

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["tip_pct"] = 100 * tips["tip"] / tips["total_bill"]

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %% [markdown]
# ### Factor plots
# Factor plots can be useful for this kind of visualization as well. This allows you to view the distribution of a parameter within bins defined by any other parameter:

# %%
with sns.axes_style(style="ticks"):
    g = sns.catplot(x="day", y="total_bill", hue="sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill")
